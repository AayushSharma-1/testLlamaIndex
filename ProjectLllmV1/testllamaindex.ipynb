# %%
# %%capture
# !pip install llama-index sentence_transformers -q
# !pip install langchain
# !pip install llama-index-embeddings-huggingface
# !pip install pinecone-client
# !pip install llama-index-vector-stores-pinecone
# !pip install llama-index-embeddings-huggingface
# !pip install -q llama-index-llms-gemini

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings
import pinecone
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
)
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.llms.gemini import Gemini
from pinecone import Pinecone, ServerlessSpec
import os

# %%
Settings.embed_model = HuggingFaceEmbedding(
    model_name="sentence-transformers/paraphrase-MiniLM-L6-v2"
)

# %%
# for i in os.listdir(r'C:\Users\aayus\Lucknow-LLM-data\Lucknow-LLM-main\Lucknow-LLM-main\lucknowllm\data\Unstructured_data'):
#     file_path = r'C:\Users\aayus\Lucknow-LLM-data\Lucknow-LLM-main\Lucknow-LLM-main\lucknowllm\data\Unstructured_data' + '\\' + str(i)
#     for j in os.listdir(file_path):
#        with open(file_path +'\\' + str(j), 'r', encoding = 'utf-8') as f:
#            data_dict['file_name'].append(str(j))
#            data_dict['data'].append(f.read())

for i in os.listdir(r'C:\Users\aayus\Lucknow-LLM-data\Lucknow-LLM-main\Lucknow-LLM-main\lucknowllm\data\Unstructured_data'):
    file_path = os.path.join(r'C:\Users\aayus\Lucknow-LLM-data\Lucknow-LLM-main\Lucknow-LLM-main\lucknowllm\data\Unstructured_data', i)
    for j in os.listdir(file_path):
        with open(os.path.join(file_path, j), 'r', encoding='utf-8') as f:
            key_name = str(j)
            data_dict[key_name] = f.read()

print(data_dict)

# %%
data_dict

# %%
import pinecone
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
)
from llama_index.vector_stores.pinecone import PineconeVectorStore

# init pinecone
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="fea6d7eb-1b48-4a28-afe5-df253dbe3e1d")
pc.create_index(
    name="quickstart",
    dimension=384, # Replace with your model dimensions
    metric="cosine", # Replace with your model metric
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    ) 
)
# construct vector store and customize storage context
storage_context = StorageContext.from_defaults(
    vector_store=PineconeVectorStore(pc.Index("quickstart"))
)

# documents = SimpleDirectoryReader(r"D:\ProjectLllmV1\all_text_file").load_data()
# # from llama_index.core import Document
# # documents = []
# # for key, val in data_dict.items():
# #     documents.append(Document(val))
# index = VectorStoreIndex.from_documents(
#     documents, storage_context=storage_context
# )

# %%
from llama_index.core.node_parser import SentenceSplitter

text_splitter = SentenceSplitter(chunk_size=400, chunk_overlap=50)

# global
from llama_index.core import Settings

Settings.text_splitter = text_splitter

# %%
documents2 = SimpleDirectoryReader(r"D:\ProjectLllmV1\all_text_file").load_data()

# %%
index = VectorStoreIndex.from_documents(
    documents2, storage_context=storage_context
)
# Out:
# Upserted vectors:   0%|          | 0/883 [00:00<?, ?it/s]

# %%
documents2
# Out:
# [Document(id_='46f87402-7b8c-44cf-a762-0426d5717f6c', embedding=None, metadata={'file_path': 'D:\\ProjectLllmV1\\all_text_file\\Ambedkar_memorial.txt', 'file_name': 'Ambedkar_memorial.txt', 'file_type': 'text/plain', 'file_size': 21551, 'creation_date': '2024-04-17', 'last_modified_date': '2024-04-14'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='The Ambedkar Memorial complex is Mayawati’s largest and most ambitious commission. Completed in 2008 at an estimated cost of seven billion rupees, the site spans more than twenty-five acres and is enclosed by a vedika-like fence.[44] It is located at the bottom of a hill, next to the Gomti river and beside a flyover, a strategic location that ensures its visibility. The vast, open, granite-lined courts, wh
# ...

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="fea6d7eb-1b48-4a28-afe5-df253dbe3e1d")
index = pc.Index("quickstart")

# %%
vector_store = PineconeVectorStore(pc.Index("quickstart"))
index = VectorStoreIndex.from_vector_store(vector_store=vector_store)

# %%
# !pip install llama-index-multi-modal-llms-gemini

# %%
# !pip install llama-index-llms-gemini

# %%
GOOGLE_API_KEY = "AIzaSyCMAvB0-ehycivbI10OaaqY9WNXUe20U7U"  # add your GOOGLE API key here

# %%
# !pip install -q llama-index-llms-gemini
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\aayus\anaconda3\lib\site-packages)

# %%
from llama_index.multi_modal_llms.gemini import GeminiMultiModal

# %%
from llama_index.llms.gemini import Gemini

# %%
llm = Gemini(api_key=GOOGLE_API_KEY, model_name='models/gemini-pro')

# %%
query_engine = index.as_query_engine(
    similarity_top_k=10,
    vector_store_query_mode="default",
    llm = llm,
    alpha=None,
    doc_ids=None,
)

# %%
reponse = query_engine.query('best food in lucknow ?')

# %%
print(reponse)
# Out:
# Some of the famous food of Lucknow are Tundey Kebab, Irdis ki Biryani, Chicken Masala, Malai Makhan, Khasta Kachori.

# %%
from llama_index.core import VectorStoreIndex, get_response_synthesizer
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core.data_structs import Node

# %%
retriver_engine = VectorIndexRetriever(
    index=index,
    similarity_top_k=10,
)

# %%
from llama_index.core import Settings
Settings.llm = llm

# %%
response_synthesizer = get_response_synthesizer()

# assemble query engine
query_engine2 = RetrieverQueryEngine(
    retriever=retriver_engine,
    response_synthesizer=response_synthesizer,
    node_postprocessors=[SimilarityPostprocessor(similarity_cutoff=0.7)],

)

# query
response = query_engine2.query("best food places in lucknow?")
print(response)
# Out:
# The provided context does not specify the best food places in Lucknow.

# %%
print(response)
# Out:
# This question cannot be answered from the given context.

# %%
retriever = index.as_retriever(response_synthesizer=response_synthesizer)
nodes = retriever.retrieve("Food of Lucknow ?")

# %%
response = response_synthesizer.synthesize(
    "query text", nodes=[Node(text="text"), ...]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 response = response_synthesizer.synthesize(
#       2     "query text", nodes=[Node(text="text"), ...]
#       3 )
#
# File c:\Users\aayus\anaconda3\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\aayus\anaconda3\lib\site-packages\llama_index\core\response_synthesizers\base.py:243, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
# ...

# %%
# from llama_index.core.data_structs import Node
# from llama_index.core.schema import NodeWithScore
# from llama_index.core import get_response_synthesizer

# response_synthesizer = get_response_synthesizer(
#     response_mode="refine",
#     service_context=service_context,
#     text_qa_template=text_qa_template,
#     refine_template=refine_template,
#     use_async=False,
#     streaming=False,
# )

# # synchronous
# response = response_synthesizer.synthesize(
#     "query string",
#     nodes=[NodeWithScore(node=Node(text="text"), score=1.0), ...],
#     additional_source_nodes=[
#         NodeWithScore(node=Node(text="text"), score=1.0),
#         ...,
#     ],
# )

# # asynchronous
# response = await response_synthesizer.asynthesize(
#     "query string",
#     nodes=[NodeWithScore(node=Node(text="text"), score=1.0), ...],
#     additional_source_nodes=[
#         NodeWithScore(node=Node(text="text"), score=1.0),
#         ...,
#     ],
# )

# %%
import os
import shutil

def move_files(source_dir, destination_dir):
    # Create the destination directory if it doesn't exist
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # A dictionary to keep track of the number of occurrences of each filename
    filename_count = {}

    # Traverse through each subdirectory in the source directory
    for subdir in os.listdir(source_dir):
        subdir_path = os.path.join(source_dir, subdir)
        
        # Check if it's a directory
        if os.path.isdir(subdir_path):
            # Traverse through each file in the subdirectory
            for file in os.listdir(subdir_path):
                file_path = os.path.join(subdir_path, file)
                # Get the filename without extension
                filename, file_extension = os.path.splitext(file)
                # Check if the filename already exists in the dictionary
                if filename in filename_count:
                    # Increment the count for this filename
                    filename_count[filename] += 1
                    # Rename the file to include the count
                    new_filename = f"{filename}_{filename_count[filename]}{file_extension}"
                else:
                    # Add the filename to the dictionary with count 1
                    filename_count[filename] = 1
                    new_filename = file
                # Move the file to the destination directory
                shutil.move(file_path, os.path.join(destination_dir, new_filename))

# Example usage
source_directory = r"C:\Users\aayus\Lucknow-LLM-data\Lucknow-LLM-main\Lucknow-LLM-main\lucknowllm\data\Unstructured_data"
destination_directory = r"D:\ProjectLllmV1\all_text_file"

move_files(source_directory, destination_directory)

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB 435.7 kB/s eta 0:00:34
#     --------------------------------------- 0.3/14.5 MB 2.2 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.5/14.5 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.8/14.5 MB 20.1 MB/s eta 0:00:01
#    -------------------- ------------------- 7.4/14.5 MB 29.6 MB/s eta 0:00:01
#    ------------------------------ --------- 11.0/14.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------  14.5/14.5 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 65.5 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\aayus\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\aayus\anaconda3\lib\site-packages)
# ...

# %%
from langchain.document_loaders import HuggingFaceDatasetLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
import os

# %%
def chunker(path):
    with open(path, 'r' , encoding='utf-8') as f:
        data = f.read()
        f.close()

    from langchain.text_splitter import CharacterTextSplitter, TokenTextSplitter, RecursiveCharacterTextSplitter
    CHUNK_SIZE = 800
    CHUNK_OVERLAP = 200

    text_splitter = RecursiveCharacterTextSplitter(chunk_size = CHUNK_SIZE, chunk_overlap = CHUNK_OVERLAP, is_separator_regex= False)
    docs = text_splitter.create_documents([data])
    docs2 = text_splitter.split_documents(docs)
    return docs2

# %%
def chunks_loader():
    chunk = []
    for i in os.listdir(r'D:\ProjectLllmV1\all_text_file'):
        file_path = r'D:\ProjectLllmV1\all_text_file' + '\\' + str(i)
        # print(file_path)
        chunk.extend(chunker(file_path))
    return chunk

# %%
docs = chunks_loader()

# %%
docs

# %%
modelPath = "sentence-transformers/paraphrase-MiniLM-L6-v2"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cpu'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
)

# %%
db = FAISS.from_documents(docs, embeddings)
db.save_local(folder_path=r"D:\ProjectLllmV1\faiss_db", index_name="myFaissIndex")

# %%
db = FAISS.load_local(folder_path=r"D:\ProjectLllmV1\faiss_db",embeddings=embeddings,index_name="myFaissIndex", allow_dangerous_deserialization=True)
searchDocs = db.similarity_search("Hospitals in lucknow")
print(searchDocs)
# Out:
# [Document(page_content="Having access to the best hospitals is essential when it comes to healthcare. Both public and private institutions provide top-notch medical care in Lucknow, the capital of Uttar Pradesh. In this article, we'll look at some of Lucknow's best hospitals, their specialty, and patient testimonials.\n\nGovernment Hospitals:\n\nSanjay Gandhi Postgraduate Institute of Medical Sciences (SGPGIMS):\nAddress: Raebareli Road, Lucknow, Uttar Pradesh 226014\nContact: 0522-2668700\nWebsite: www.sgpgi.ac.in\nSpecialty: SGPGIMS is a premier institute known for its super-specialty medical services. It has a wide range of departments, including neurology, cardiology, gastroenterology, and more."), Document(page_content="Dr. D. P. Singh (Not mentioned)\nAddress: Not available\nContact: Not available\nSpecialty: Orthopedician.\n\nConclusion:\nBoth the public and private healthcare systems are well-developed in Lucknow. Private hospitals like Apollomedics and Medanta have cutting-e
# ...

# %%
retriever = db.as_retriever()
docs = retriever.invoke('Hospitals of Lucknow ?')
print(docs)
# Out:
# [Document(page_content="Dr. D. P. Singh (Not mentioned)\nAddress: Not available\nContact: Not available\nSpecialty: Orthopedician.\n\nConclusion:\nBoth the public and private healthcare systems are well-developed in Lucknow. Private hospitals like Apollomedics and Medanta have cutting-edge facilities and skilled medical staff, while government hospitals like SGPGIMS and KGMU are renowned for their super-specialty services. Although there are differences in the experiences that patients have in different facilities, Lucknow's healthcare system is nonetheless thriving and meets a wide range of medical needs. People are urged to do their homework and get recommendations from reliable sources before selecting a hospital to locate the one that would best meet their needs."), Document(page_content='LUCKNOW Society'), Document(page_content="Having access to the best hospitals is essential when it comes to healthcare. Both public and private institutions provide top-notch medical care in Luc
# ...

# %%
db2 = FAISS.load_local(folder_path=r'D:\ProjectLllmV1\lai_rag\lai_rag',embeddings=embeddings,index_name="index", allow_dangerous_deserialization=True)
searchDocs2 = db2.similarity_search("Food of Lucknow?")
print(searchDocs2[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[46], line 2
#       1 db2 = FAISS.load_local(folder_path=r'D:\ProjectLllmV1\lai_rag\lai_rag',embeddings=embeddings,index_name="index", allow_dangerous_deserialization=True)
# ----> 2 searchDocs2 = db2.similarity_search("Food of Lucknow?")
#       3 print(searchDocs2[0].page_content)
#
# File c:\Users\aayus\anaconda3\lib\site-packages\langchain_community\vectorstores\faiss.py:530, in FAISS.similarity_search(self, query, k, filter, fetch_k, **kwargs)
#     510 def similarity_search(
#     511     self,
#     512     query: str,
#    (...)
#     516     **kwargs: Any,
#     517 ) -> List[Document]:
#     518     """Return docs most similar to query.
#     519
#     520     Args:
#    (...)
#     528         List of Documents most similar to the query.
#     529     """
# ...
